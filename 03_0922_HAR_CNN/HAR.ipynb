# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns


def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = np.dstack(loaded)
    return loaded

# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y


# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
    # load all train
    trainX, trainy = load_dataset_group('train', prefix + './HAR/UCI/')
    # load all test
    testX, testy = load_dataset_group('test', prefix + './HAR/UCI/')
    
    #zero-offset class values
    trainy = trainy - 1
    testy = testy - 1
    #one hot encode y
    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)
    print(trainX.shape, trainy.shape, trainy_one_hot.shape, testX.shape, testy.shape, testy_one_hot.shape)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %%
X_train, y_train, y_train_one_hot, X_test, y_test, y_test_one_hot = load_dataset()
# Out:
# (7352, 128, 9) (7352, 1) (7352, 6) (2947, 128, 9) (2947, 1) (2947, 6)

# %%
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train_one_hot.shape[1]

# %%
n_timesteps, n_features, n_outputs
# Out:
# (128, 9, 6)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from keras.layers import concatenate
from keras.utils import to_categorical

# %%
##Level_1
# layer 1
inputs1_1= Input(shape=(n_timesteps,n_features))##128,9
conv1_1 = Conv1D(filters=128, kernel_size=3, activation='relu')(inputs1_1) ##none,126,128
# layer 2
inputs1_2= Input(shape=(n_timesteps,n_features))
conv1_2 = Conv1D(filters=128, kernel_size=5, activation='relu')(inputs1_2)##124,128
# layer 3
inputs1_3= Input(shape=(n_timesteps,n_features))
conv1_3 = Conv1D(filters=128, kernel_size=7, activation='relu')(inputs1_3)##122,128
# layer 4
inputs1_4= Input(shape=(n_timesteps,n_features))
conv1_4 = Conv1D(filters=128, kernel_size=9, activation='relu')(inputs1_4)##120,128

# merge1
merged_1 = concatenate([conv1_1,conv1_2,conv1_3,conv1_4],axis=1)

#maxpool1
pool_1=MaxPooling1D(pool_size=5)(merged_1)

##Level_2
# layer 1
conv2_1 = Conv1D(filters=64, kernel_size=3, activation='relu')(pool_1)
# layer 2
conv2_2 = Conv1D(filters=64, kernel_size=5, activation='relu')(pool_1)
# layer 3
conv2_3 = Conv1D(filters=64, kernel_size=7, activation='relu')(pool_1)
# layer 4

conv2_4 = Conv1D(filters=64, kernel_size=9, activation='relu')(pool_1) 
# merge2
merged_2 = concatenate([conv2_1,conv2_2,conv2_3,conv2_4],axis=1)

#maxpool2
pool_2=MaxPooling1D(pool_size=5)(merged_2)


##Level_3
# layer 1
conv3_1 = Conv1D(filters=32, kernel_size=3, activation='relu')(pool_2)
# layer 2
conv3_2 = Conv1D(filters=32, kernel_size=5, activation='relu')(pool_2)
# layer 3
conv3_3 = Conv1D(filters=32, kernel_size=7, activation='relu')(pool_2)
# layer 4

conv3_4 = Conv1D(filters=32, kernel_size=9, activation='relu')(pool_2) 
# merge2
merged_3 = concatenate([conv3_1,conv3_2,conv3_3,conv3_4],axis=1)

#maxpool2
pool_3=MaxPooling1D(pool_size=5)(merged_3)


#flatten
flat_cnn=Flatten()(pool_3)

##dense layer
dense = Dense(512, activation='relu')(flat_cnn)
outputs = Dense(n_outputs, activation='softmax')(dense)

##MODEL
cnn3_model = Model([inputs1_1, inputs1_2, inputs1_3,inputs1_4], outputs)

cnn3_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
cnn3_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 9)]             0         []
#
#  input_2 (InputLayer)        [(None, 128, 9)]             0         []
#
#  input_3 (InputLayer)        [(None, 128, 9)]             0         []
#
#  input_4 (InputLayer)        [(None, 128, 9)]             0         []
#
#  conv1d (Conv1D)             (None, 126, 128)             3584      ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 124, 128)             5888      ['input_2[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 122, 128)             8192      ['input_3[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 120, 128)             10496     ['input_4[0][0]']
#
#  concatenate (Concatenate)   (None, 492, 128)             0         ['conv1d[0][0]',
#                                                                      'conv1d_1[0][0]',
#                                                                      'conv1d_2[0][0]',
#                                                                      'conv1d_3[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 98, 128)              0         ['concatenate[0][0]']
#  D)
#
#  conv1d_4 (Conv1D)           (None, 96, 64)               24640     ['max_pooling1d[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 94, 64)               41024     ['max_pooling1d[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 92, 64)               57408     ['max_pooling1d[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 90, 64)               73792     ['max_pooling1d[0][0]']
#
#  concatenate_1 (Concatenate  (None, 372, 64)              0         ['conv1d_4[0][0]',
#  )                                                                   'conv1d_5[0][0]',
#                                                                      'conv1d_6[0][0]',
#                                                                      'conv1d_7[0][0]']
#
#  max_pooling1d_1 (MaxPoolin  (None, 74, 64)               0         ['concatenate_1[0][0]']
#  g1D)
#
#  conv1d_8 (Conv1D)           (None, 72, 32)               6176      ['max_pooling1d_1[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 70, 32)               10272     ['max_pooling1d_1[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 68, 32)               14368     ['max_pooling1d_1[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 66, 32)               18464     ['max_pooling1d_1[0][0]']
#
#  concatenate_2 (Concatenate  (None, 276, 32)              0         ['conv1d_8[0][0]',
#  )                                                                   'conv1d_9[0][0]',
#                                                                      'conv1d_10[0][0]',
#                                                                      'conv1d_11[0][0]']
#
#  max_pooling1d_2 (MaxPoolin  (None, 55, 32)               0         ['concatenate_2[0][0]']
#  g1D)
#
#  flatten (Flatten)           (None, 1760)                 0         ['max_pooling1d_2[0][0]']
#
#  dense (Dense)               (None, 512)                  901632    ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 6)                    3078      ['dense[0][0]']
#
# ==================================================================================================
# Total params: 1179014 (4.50 MB)
# Trainable params: 1179014 (4.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# fit network
model_history=cnn3_model.fit(x=[X_train,X_train,X_train,X_train], y=y_train_one_hot, epochs=30, batch_size=32,validation_data= ([testX,testX,testX,testX],testy_one_hot))
# Out:
# Epoch 1/30
# 230/230 [==============================] - 18s 70ms/step - loss: 0.2811 - accuracy: 0.8830 - val_loss: 0.1965 - val_accuracy: 0.9094
# Epoch 2/30
# 230/230 [==============================] - 16s 70ms/step - loss: 0.1132 - accuracy: 0.9547 - val_loss: 0.2316 - val_accuracy: 0.9152
# Epoch 3/30
# 230/230 [==============================] - 17s 73ms/step - loss: 0.1015 - accuracy: 0.9544 - val_loss: 0.1805 - val_accuracy: 0.9257
# Epoch 4/30
# 230/230 [==============================] - 17s 74ms/step - loss: 0.1215 - accuracy: 0.9510 - val_loss: 0.2483 - val_accuracy: 0.9060
# Epoch 5/30
# 230/230 [==============================] - 16s 68ms/step - loss: 0.0951 - accuracy: 0.9595 - val_loss: 0.1886 - val_accuracy: 0.9260
# Epoch 6/30
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0841 - accuracy: 0.9648 - val_loss: 0.2085 - val_accuracy: 0.9281
# Epoch 7/30
# 230/230 [==============================] - 17s 73ms/step - loss: 0.0852 - accuracy: 0.9649 - val_loss: 0.2597 - val_accuracy: 0.9264
# Epoch 8/30
# 230/230 [==============================] - 16s 68ms/step - loss: 0.0846 - accuracy: 0.9678 - val_loss: 0.2309 - val_accuracy: 0.9311
# Epoch 9/30
# 230/230 [==============================] - 16s 68ms/step - loss: 0.0638 - accuracy: 0.9714 - val_loss: 0.2502 - val_accuracy: 0.9369
# Epoch 10/30
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0618 - accuracy: 0.9765 - val_loss: 0.4490 - val_accuracy: 0.9199
# Epoch 11/30
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0627 - accuracy: 0.9762 - val_loss: 0.4483 - val_accuracy: 0.9196
# Epoch 12/30
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0445 - accuracy: 0.9803 - val_loss: 0.5529 - val_accuracy: 0.9301
# Epoch 13/30
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0409 - accuracy: 0.9838 - val_loss: 0.5517 - val_accuracy: 0.9301
# Epoch 14/30
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0402 - accuracy: 0.9818 - val_loss: 0.5727 - val_accuracy: 0.9315
# Epoch 15/30
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0708 - accuracy: 0.9776 - val_loss: 0.2959 - val_accuracy: 0.9362
# Epoch 16/30
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0365 - accuracy: 0.9852 - val_loss: 0.3443 - val_accuracy: 0.9213
# Epoch 17/30
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0322 - accuracy: 0.9882 - val_loss: 0.3191 - val_accuracy: 0.9416
# Epoch 18/30
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0288 - accuracy: 0.9879 - val_loss: 0.3024 - val_accuracy: 0.9342
# Epoch 19/30
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0207 - accuracy: 0.9924 - val_loss: 0.3637 - val_accuracy: 0.9342
# Epoch 20/30
# 230/230 [==============================] - 16s 70ms/step - loss: 0.0262 - accuracy: 0.9882 - val_loss: 0.3643 - val_accuracy: 0.9277
# Epoch 21/30
# 230/230 [==============================] - 16s 71ms/step - loss: 0.0233 - accuracy: 0.9906 - val_loss: 0.3434 - val_accuracy: 0.9301
# Epoch 22/30
# 230/230 [==============================] - 16s 71ms/step - loss: 0.0443 - accuracy: 0.9867 - val_loss: 0.5974 - val_accuracy: 0.8968
# Epoch 23/30
# 230/230 [==============================] - 16s 70ms/step - loss: 0.0396 - accuracy: 0.9878 - val_loss: 0.5352 - val_accuracy: 0.9274
# Epoch 24/30
# 230/230 [==============================] - 16s 71ms/step - loss: 0.0200 - accuracy: 0.9924 - val_loss: 0.5391 - val_accuracy: 0.9332
# Epoch 25/30
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0153 - accuracy: 0.9929 - val_loss: 0.3896 - val_accuracy: 0.9393
# Epoch 26/30
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0234 - accuracy: 0.9917 - val_loss: 0.4095 - val_accuracy: 0.9386
# Epoch 27/30
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.4139 - val_accuracy: 0.9410
# Epoch 28/30
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0138 - accuracy: 0.9952 - val_loss: 0.4125 - val_accuracy: 0.9406
# Epoch 29/30
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0132 - accuracy: 0.9956 - val_loss: 0.4856 - val_accuracy: 0.9389
# Epoch 30/30
# 230/230 [==============================] - 16s 70ms/step - loss: 0.0184 - accuracy: 0.9927 - val_loss: 0.5204 - val_accuracy: 0.9335

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
pred=cnn3_model.predict([testX,testX,testX,testX])
pred=np.argmax(pred, axis=-1)
cm=confusion_matrix(testy,pred)
print(cm)
print(accuracy_score(testy,pred))
print(classification_report(testy,pred))
sns.heatmap(cm, annot=True, fmt = '.2f')
# Out:
# 93/93 [==============================] - 2s 17ms/step
# [[467   3  25   1   0   0]
#  [  1 448  22   0   0   0]
#  [  0   0 420   0   0   0]
#  [  0   2   0 393  96   0]
#  [  0   0   0  19 513   0]
#  [  0  27   0   0   0 510]]
# 0.9334916864608076
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97       496
#            1       0.93      0.95      0.94       471
#            2       0.90      1.00      0.95       420
#            3       0.95      0.80      0.87       491
#            4       0.84      0.96      0.90       532
#            5       1.00      0.95      0.97       537
#
#     accuracy                           0.93      2947
#    macro avg       0.94      0.93      0.93      2947
# weighted avg       0.94      0.93      0.93      2947
# <Axes: >
